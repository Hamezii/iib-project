# %%
import _003_extended_stp as stp
import torch
import matplotlib.pyplot as plt

# %%
for alpha in (1.0,):#(0.5, 1, 1.5, 2, 2.5, 5):
    m = stp.STPModel(alpha=alpha)
    times = torch.linspace(-10, 30, 100)
    x = m.compute_R(times)
    #print(x)
    plt.plot(times, x)
    print(m.compute_R(torch.Tensor([-1, 0, 1])))
# Out:
# tensor([0.3133, 0.6931, 1.3133])
